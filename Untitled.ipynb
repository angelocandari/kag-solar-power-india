# %%
import pandas as pd

# %%
df = pd.read_csv('../src/solar_power_generation_india/Plant_1_Generation_Data.csv', parse_dates=['DATE_TIME'])

# %%
df.head()
# Out:
#    DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0 2020-05-15   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 1 2020-05-15   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 2 2020-05-15   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
# 3 2020-05-15   4135001  7JYdWkrLSPkdwr4       0.0       0.0          0.0
# 4 2020-05-15   4135001  McdE0feGgRqW7Ca       0.0       0.0          0.0
#
#    TOTAL_YIELD
# 0    6259559.0
# 1    6183645.0
# 2    6987759.0
# 3    7602960.0
# 4    7158964.0

# %%
df.shape
# Out:
# (68778, 7)

# %%
df.dtypes
# Out:
# DATE_TIME      datetime64[ns]
# PLANT_ID                int64
# SOURCE_KEY             object
# DC_POWER              float64
# AC_POWER              float64
# DAILY_YIELD           float64
# TOTAL_YIELD           float64
# dtype: object

# %%
df.groupby(['PLANT_ID', df['DATE_TIME'].dt.date])[['DC_POWER', 'AC_POWER', 'DAILY_YIELD']].sum()
# Out:
#                          DC_POWER       AC_POWER   DAILY_YIELD
# PLANT_ID DATE_TIME
# 4135001  2020-01-06  5.210134e+06  509691.499996  6.387988e+06
#          2020-02-06  6.631811e+06  648667.570833  6.224743e+06
#          2020-03-06  6.732591e+06  658508.402385  7.677981e+06
#          2020-04-06  7.321031e+06  715775.188695  6.091402e+06
#          2020-05-06  6.898474e+06  674574.155957  6.384127e+06
#          2020-05-15  5.627239e+06  550830.959402  5.053591e+06
#          2020-05-16  5.806138e+06  568359.821428  6.699905e+06
#          2020-05-17  6.759595e+06  660975.389285  7.804065e+06
#          2020-05-18  4.812549e+06  470969.708929  5.130290e+06
#          2020-05-19  5.437955e+06  532250.491070  5.896321e+06
#          2020-05-20  5.375586e+06  525084.567381  5.612536e+06
#          2020-05-21  6.781068e+06  662742.449405  6.627303e+06
#          2020-05-22  6.420685e+06  627830.107975  5.555931e+06
#          2020-05-23  7.630217e+06  745884.287974  8.468993e+06
# ...
